# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# # Univariate Analysis

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
#droping the data that is not useful in analysis
df1=df.drop(['Country','Region','Happiness Rank','Standard Error'],axis=1)

# %%
df1.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
for i in df1.columns:
    
    sns.distplot(df1[i])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# observation:We can observe skewness in most ofthe columns

# %%
for i in df1.columns:
    
    sns.boxplot(df1[i])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# Observation:we can that there might besome outliers for 'family','Trust(Government Corruption)','Generosity','Dystopia residual'

# %% [markdown]
# # Bivariate analysis

# %%
sns.pairplot(df1)

# %%
df1.corr()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.780966
# Economy (GDP per Capita)              0.780966                  1.000000
# Family                                0.740605                  0.645299
# Health (Life Expectancy)              0.724200                  0.816478
# Freedom                               0.568211                  0.370300
# Trust (Government Corruption)         0.395199                  0.307885
# Generosity                            0.180319                 -0.010465
# Dystopia Residual                     0.530474                  0.040059
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.740605                  0.724200  0.568211
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# ...

# %%
plt.figure(figsize=(25,17))
sns.heatmap(df1.corr(),annot=True,linewidths=0.5,linecolor='yellow',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing multi collinearity problem

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df1.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
x=df1.drop(['Happiness Score'],axis=1)

# %%
vif=pd.DataFrame()

# %%
vif['Variables']=x.columns

# %%
vif['VIF factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]

# %%
vif
# Out:
#                        Variables  VIF factor
# 0       Economy (GDP per Capita)   21.747540
# 1                         Family   24.586246
# 2       Health (Life Expectancy)   22.884262
# 3                        Freedom   15.791462
# 4  Trust (Government Corruption)    3.464681
# 5                     Generosity    5.520157
# 6              Dystopia Residual    9.948714

# %%
sns.boxplot(df['Family'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Family'>

# %%
sns.distplot(df['Happiness Score','Family'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
df2=df1.drop(['Family'],axis=1) #very high vif value and high skewness with outliers

# %% [markdown]
# # Removing outliers using zscore

# %%
#Removing outliers using zscore
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df2))

# %%
df_new=df2[(z<3).all(axis=1)]

# %%
df2.shape
# Out:
# (158, 7)

# %%
df_new.shape
# Out:
# (154, 7)

# %%
#divide dataframe into features and label
x=df_new.drop(['Happiness Score'],axis=1)
y=df_new['Happiness Score']

# %% [markdown]
# # Removing skewness from data

# %%
x.skew()
# Out:
# Economy (GDP per Capita)        -0.386812
# Health (Life Expectancy)        -0.712053
# Freedom                         -0.407170
# Trust (Government Corruption)    1.305766
# Generosity                       0.657506
# Dystopia Residual               -0.044493
# dtype: float64

# %%
#removing complete skewness
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()

# %%
#splitting the dataframe
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(pred_train,y_train)*100,1)==round(r2_score(pred_test,y_test)*100,1):
        print('At random state',i,'the model performs verywell')
        print('At random state',i)
        print("the training accuacy is",r2_score(pred_train,y_train)*100)
        print("the testing accuacy is",r2_score(pred_test,y_test)*100)
# Out:
# At random state 8 the model performs verywell
# At random state 8
# the training accuacy is 96.37475341713818
# the testing accuacy is 96.39178547598047
# At random state 51 the model performs verywell
# At random state 51
# the training accuacy is 96.27846604270759
# the testing accuacy is 96.34491426352749
# At random state 146 the model performs verywell
# At random state 146
# the training accuacy is 96.26096313826272
# the testing accuacy is 96.3336881784272
# At random state 181 the model performs verywell
# At random state 181
# the training accuacy is 96.33679662567955
# the testing accuacy is 96.30414659597176
# At random state 261 the model performs verywell
# At random state 261
# the training accuacy is 96.28977590580041
# the testing accuacy is 96.34827912555866
# At random state 302 the model performs verywell
# At random state 302
# the training accuacy is 96.310939006423
# the testing accuacy is 96.32057804696193
# At random state 379 the model performs verywell
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=8)
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
pred_train=lr.predict(x_train)

# %%
mean_absolute_error(y_test,pred_test)
# Out:
# 0.1403366243831391

# %%
np.sqrt(mean_squared_error(y_test,pred_test))
# Out:
# 0.2305638351656714

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9640068848265148

# %%
r2_score(y_train,pred_train)
# Out:
# 0.965015797767362

# %% [markdown]
# # XGBoost Model

# %%
from xgboost import XGBRegressor

# %%
xg=XGBRegressor()

# %%
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
pred_test=xg.predict(x_test)
pred_train=xg.predict(x_train)

# %%
np.sqrt(mean_squared_error(y_test,pred_test))
# Out:
# 0.3531869936623938

# %%
mean_absolute_error(y_test,pred_test)
# Out:
# 0.2829420098950787

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9155408969164387

# %%
r2_score(y_train,pred_train)
# Out:
# 0.9999994264662483

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_test=rf.predict(x_test)
pred_train=rf.predict(x_train)

# %%
np.sqrt(mean_squared_error(y_test,pred_test))
# Out:
# 0.3748929681922566

# %%
mean_absolute_error(y_test,pred_test)
# Out:
# 0.30025419354838756

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9048406098582089

# %%
#Hypertuning using grid search cv
n_estimators=[100, 200, 500,600,800 ]
max_features=[0.2,0.6,0.8,0.4,1,'auto','sqrt','log2']
max_depth=[10, 20, 30, 40, 50, None]
bootstrap=[True, False]
max_samples=[0.5,0.75,1]

# %%
param_grid={'bootstrap': [True, False],
               
               'max_features': ['auto','sqrt','log2'],
               'min_samples_leaf': [1, 2],
               'max_samples': [0.5,0.75,1],
               'n_estimators': [200, 500,600],
                'max_depth':[30, 40, 50, None],'min_samples_split': [2, 5, 10]}

# %%
rf_grid=GridSearchCV(estimator=rf,param_grid=param_grid,cv=5,verbose=5,n_jobs=-1)

# %%
rf_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 1944 candidates, totalling 9720 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-243-eddeb49b29d4> in <module>
# ----> 1 rf_grid.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ...

# %% [markdown]
# # Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
sv=SVR()

# %%
sv.fit(x_train,y_train)
# Out:
# SVR()

# %%
pred_train=sv.predict(x_train)
pred_test=sv.predict(x_test)

# %%
mean_absolute_error(y_train,pred_train)
# Out:
# 0.12784835371285344

# %%
mean_absolute_error(y_test,pred_test)
# Out:
# 0.2438957357382475

# %%
np.sqrt(mean_squared_error(y_test,pred_test))
# Out:
# 0.3048555966829572

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9370746838978938

# %%
param_grid = {'C': [0.1, 1,100, 1000],
              'gamma': [ 0.01, 0.001, 0.0001],
              'kernel': ['rbf','linear','poly']}

# %%
sv_grid=GridSearchCV(estimator=sv,param_grid=param_grid,cv=5,verbose=5,n_jobs=-1)

# %%
sv_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 100, 1000],
#                          'gamma': [0.01, 0.001, 0.0001],
#                          'kernel': ['rbf', 'linear', 'poly']},
#              verbose=5)

# %%
sv_grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
sv=SVR(C=1000,gamma=0.001,kernel='rbf')

# %%
pred_train=sv_grid.predict(x_train)
pred_test=sv_grid.predict(x_test)

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9714410247332838

# %%
sv_grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %% [markdown]
# # LassoRegression

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
ls=Lasso(alpha=0.0001)

# %%
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
pred_train=ls.predict(x_train)
pred_test=ls.predict(x_test)

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9700878535040097

# %%
r2_score(y_train,pred_train)
# Out:
# 0.9630956006234759

# %%
rd=Ridge(alpha=0.0001)

# %%
rd.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
pred_train=rd.predict(x_train)
pred_test=rd.predict(x_test)

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9700648670594223

# %% [markdown]
# # Observation: Support vector regressor giving best socre it is the best model

# %%
#model saving
import pickle
filename='world_happiness_score.pkl'
pickle.dump(sv,open(filename,'wb'))
